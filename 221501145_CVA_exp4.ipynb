# %% [markdown]
# <a href="https://colab.research.google.com/github/SubashiniB181203/Computer_Vision_Lab/blob/main/221501145_CVA_exp4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import cv2

# %%
# You can do this via pip (if not already installed):
# !pip install torch torchvision
# !git clone https://github.com/ultralytics/yolov5.git
# !cd yolov5 && pip install -r requirements.txt

model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2025-5-2 Python-3.11.12 torch-2.6.0+cu124 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
image_path = "/content/sample_data/pexels-rdne-7516817.jpg"
img = cv2.imread(image_path)

# %%
height, width = img.shape[:2]
new_width = width * 2  # Double the width
new_height = height * 2  # Double the height

# %%
# Resize the image
img_resized = cv2.resize(img, (new_width, new_height))

# %%
# Convert the image from BGR (OpenCV default) to RGB (YOLOv5 input)
img_rgb = cv2.cvtColor(img_resized, cv2.COLOR_BGR2RGB)

# %%
results = model(img_rgb)
results.show()
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Buffered data was truncated after reaching the output size limit.
